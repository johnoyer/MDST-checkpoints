# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pandas.read_csv('../data/states_edu.csv')
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
df.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'GRADES_PK_G', 'GRADES_KG_G',
#        'GRADES_4_G', 'GRADES_8_G', 'GRADES_12_G', 'GRADES_1_8_G',
#        'GRADES_9_12_G', 'GRADES_ALL_G', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: INSTRUCTION_EXPENDITURE

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
len(df['YEAR'].unique())
# Out:
# 33

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
df.groupby('STATE')["INSTRUCTION_EXPENDITURE"].mean()
# Out:
# STATE
# ALABAMA                  2937209.32
# ALASKA                    892252.12
# ARIZONA                  3024480.36
# ARKANSAS                 1887682.80
# CALIFORNIA              27882975.88
# COLORADO                 3198272.48
# CONNECTICUT              4051110.08
# DELAWARE                  725517.84
# DISTRICT_OF_COLUMBIA      437580.64
# FLORIDA                 10426097.52
# GEORGIA                  7228747.36
# HAWAII                    984035.60
# IDAHO                     902472.12
# ILLINOIS                10859165.76
# INDIANA                  4631250.12
# IOWA                     2356155.92
# KANSAS                   2174052.56
# KENTUCKY                 2764382.52
# LOUISIANA                3117506.92
# MAINE                    1179294.36
# MARYLAND                 5171972.44
# MASSACHUSETTS            6712542.16
# MICHIGAN                 8097297.48
# MINNESOTA                4514928.48
# MISSISSIPPI              1768744.16
# MISSOURI                 4033045.04
# ...

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
df.groupby('YEAR')["INSTRUCTION_EXPENDITURE"].mean()
print('2019 data not available')
# Out:
# 2019 data not available

# %% [markdown]
# Find the maximum outcome score for every state.
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
df.groupby('STATE')["INSTRUCTION_EXPENDITURE"].max()
# Out:
# STATE
# ALABAMA                  3947003.0
# ALASKA                   1484610.0
# ARIZONA                  4296503.0
# ARKANSAS                 2658253.0
# CALIFORNIA              42587272.0
# COLORADO                 4786838.0
# CONNECTICUT              6110631.0
# DELAWARE                 1126775.0
# DISTRICT_OF_COLUMBIA      594396.0
# FLORIDA                 15212112.0
# GEORGIA                 10534931.0
# HAWAII                   1468044.0
# IDAHO                    1171313.0
# ILLINOIS                17804976.0
# INDIANA                  5746633.0
# IOWA                     3447707.0
# KANSAS                   3051755.0
# KENTUCKY                 3917968.0
# LOUISIANA                4365583.0
# MAINE                    1459635.0
# MARYLAND                 7779504.0
# MASSACHUSETTS            9991819.0
# MICHIGAN                 9608877.0
# MINNESOTA                6548885.0
# MISSISSIPPI              2407637.0
# MISSOURI                 5488433.0
# ...

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
df['INSTRUCTIONTOTAL_EXPENDITURE'] = df['INSTRUCTION_EXPENDITURE'] / df['TOTAL_EXPENDITURE']

# %% [markdown]
# Feature engineering justification: I created a new variable to store the percentage of total expenditure that is spent on instruction, because this more accurately captures what I will try to investigate when determining relationships with other variables.

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
df.plot.scatter(x='INSTRUCTIONTOTAL_EXPENDITURE', y='AVG_MATH_8_SCORE', alpha=0.6)
plt.xlabel('Instructional Expenditure/Total Expenditure')
plt.ylabel('8th Grade Math Score')
# Out:
# Text(0, 0.5, '8th Grade Math Score')

# %% [markdown]
# There does not appear to be a clear and strong relationship between instructional expenditure/total expenditure and 8th grade math score. Of the few cases where there is an abnormally low 8th grade math score, the ratio between instructional and total expenditure is lower than average. However, this does not indicate a definitive relationship.

# %% [markdown]
# **Visualization 2**

# %%
df.plot.scatter(x='INSTRUCTIONTOTAL_EXPENDITURE', y='GRADES_PK_G', alpha=0.6)
plt.xlabel('Instructional Expenditure/Total Expenditure')
plt.ylabel('Pre-K enrollment')
# Out:
# Text(0, 0.5, 'Pre-K enrollment')

# %% [markdown]
# There does not appear to be a clear relationship between instructional expenditure/total expenditure and pre-k enrollment. Among pre-k enrollments greater than 50000, there appears to be a negative relationship between instructional expenditure/total expendtiure and pre-k enrollment, although this trend does not appear at lower values. Schools with a low ratio of instructional expenditure to total expenditure tend to have very low pre-k populations, while those with a higher ratio have pre-k populations less than about 60000.

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['INSTRUCTION_EXPENDITURE','AVG_MATH_8_SCORE','GRADES_PK_G']].dropna()
y = df.loc[X.index]['INSTRUCTIONTOTAL_EXPENDITURE']

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#      X, y, test_size=, random_state=42)
y.fillna(y.mean(), inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=3)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
print(model.intercept_)
print(model.coef_)
print(model.score(X_test, y_test))
print(np.mean((model.predict(X_test)-y_test)**2)**0.5)
# Out:
# 0.43513320840826125
# [ 2.72213499e-09  2.81317873e-04 -5.07258920e-07]
# 0.0011805690437544092
# 0.040356570817443774

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'GRADES_PK_G'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Pre-K Enrollment')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = 'GRADES_PK_G'

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('NAME OF THE PREDICTOR')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# My goal was to determine if there is any significant relationship between the input variables "pre-k enrollment," "average 8th grade math score," and "instructional expenditure" and the response variable "instructional expenditure/total expenditure." I found that there is not a clear relationship between any of the input variables and the response variable, as the coefficient of determination was well below 1% and there did not seem to be a clear relationship between any of the input variables and the response during testing. The training and testing predicted data do not appear to be too bad in the case of assessing the affect of enrollent in pre-k on the response, but a large amount of variation is not capture by the model. The linear regression in this case did not perform well, as any possible relationship between the input variables and response variable does not appear to be linear and therefore could not be captured by this model.
